# %% [markdown]
# #### **Welcome to Assignment 6 on Deep Learning for Computer Vision.**
# This assignment will be of a different format than the previous assignments you did in this course. When you start working on deep learning projects in industry/academia, there'll be situations where you may have to understand implementations of popular papers and make modifications to suit your needs.
#
# So, for Part-1 of this assignment, we'll ask you to go through the official implementation of the CycleGAN paper and answer a few questions. The questions will test your understanding of Python, PyTorch, along with your knowledge of CycleGAN paper.
#
# #### **Instructions**
# 1. Use Python 3.x to run this notebook
# 2. Write your code only in between the lines 'YOUR CODE STARTS HERE' and 'YOUR CODE ENDS HERE'.
# you should not change anything else in the code cells, if you do, the answers you are supposed to get at the end of this assignment might be wrong.
# 3. Read documentation of each function carefully.
# 4. All the Best!

# %% [markdown]
# ### Part-1
#
# Please follow the instructions below and answer the questions
#
# 1. Read the original [CycleGAN paper](https://arxiv.org/abs/1703.10593) and go through the [official implementation](https://github.com/junyanz/pytorch-CycleGAN-and-pix2pix) of this paper
#      - Before running any of the code, we encourage you to go through the README and understand the workings of the code repository.
#
# 3. Now open [CycleGAN.ipynb](https://github.com/junyanz/pytorch-CycleGAN-and-pix2pix/blob/master/CycleGAN.ipynb) file in colab and run the notebook (the notebook already has a github-button for this) . Don't run the training part, skip that cell and run everything else.
#
# 3. Now once you understand the input and output parts of the code, navigate through the code repository to understadning how different functionalities are implemented and answer the questions below!

# %% [markdown]
# #### Question-1
#
# Navigate to the definition of CycleGAN model in the code repository and find the forward pass. What operation is that performing? (Assume $X$ denotes original image from the first domain and $Y$ denotes the original image from the second domain)
#
# 1.  $ \hat{X} \rightarrow \hat{Y} \rightarrow \hat{X} $ and $ Y \rightarrow \hat{X} \rightarrow \hat{Y} $
# 2.  $ X \rightarrow \hat{Y} \rightarrow \hat{X} $ and $ Y \rightarrow \hat{X} \rightarrow \hat{Y} $
# 3. $ X \rightarrow \hat{Y} \rightarrow \hat{X} $ and $ \hat{Y} \rightarrow \hat{X} \rightarrow \hat{Y} $
# 4. $ X \rightarrow Y \rightarrow \hat{X} $ and $ Y \rightarrow X \rightarrow \hat{Y} $
#
# Answer: (2)$ X \rightarrow \hat{Y} \rightarrow \hat{X} $ and $ Y \rightarrow \hat{X} \rightarrow \hat{Y} $

# %% [markdown]
# #### Question-2
#
# How many losses does the code for CycleGAN use in total?
# 1. 3
# 2. 6
# 3. 4
# 4. 8
#
# Answer: 8

# %% [markdown]
# #### Question-3
#
# What weight initialisation does the CycleGAN implementation use?
# 1. Xavier
# 2. Normal
# 3. Kaiming
# 4. Orthogonal
#
# Answer: Normal

# %% [markdown]
# ### Part-2
#
#
# For this part, you have to go through the official PyTorch example on [super-resolution](https://github.com/pytorch/examples.git) and answer the questions below

# %%
# !git clone https://github.com/pytorch/examples.git
# Out:
# Cloning into 'examples'...
# remote: Enumerating objects: 2596, done.
# remote: Total 2596 (delta 0), reused 0 (delta 0), pack-reused 2596
# Receiving objects: 100% (2596/2596), 39.10 MiB | 13.22 MiB/s, done.
# Resolving deltas: 100% (1291/1291), done.

# %%
import os
os.chdir('examples/super_resolution')

# %%
# !ls
# Out:
# data.py  dataset.py  main.py  model.py	README.md  super_resolve.py

# %%
# !python main.py --upscale_factor 3 --batchSize 16 --nEpochs 20 --lr 0.001
# Out:
# Namespace(batchSize=16, cuda=False, lr=0.001, nEpochs=20, seed=123, testBatchSize=10, threads=4, upscale_factor=3)
# ===> Loading datasets
# ===> Building model
# ===> Epoch[1](1/13): Loss: 0.3907
# ===> Epoch[1](2/13): Loss: 0.1766
# ===> Epoch[1](3/13): Loss: 0.0575
# ===> Epoch[1](4/13): Loss: 0.0586
# ===> Epoch[1](5/13): Loss: 0.0516
# ===> Epoch[1](6/13): Loss: 0.0485
# ===> Epoch[1](7/13): Loss: 0.0438
# ===> Epoch[1](8/13): Loss: 0.0392
# ===> Epoch[1](9/13): Loss: 0.0228
# ===> Epoch[1](10/13): Loss: 0.0208
# ===> Epoch[1](11/13): Loss: 0.0242
# ===> Epoch[1](12/13): Loss: 0.0238
# ===> Epoch[1](13/13): Loss: 0.0280
# ===> Epoch 1 Complete: Avg. Loss: 0.0759
# ===> Avg. PSNR: 15.8545 dB
# Checkpoint saved to model_epoch_1.pth
# ===> Epoch[2](1/13): Loss: 0.0248
# ===> Epoch[2](2/13): Loss: 0.0226
# ===> Epoch[2](3/13): Loss: 0.0151
# ===> Epoch[2](4/13): Loss: 0.0183
# ===> Epoch[2](5/13): Loss: 0.0149
# ===> Epoch[2](6/13): Loss: 0.0138
# ===> Epoch[2](7/13): Loss: 0.0139
# ...

# %% [markdown]
# #### Question-5
#
# Use the code provided in the repository and train a model with the following set of hyper-parameters `upscale_factor` of 3, `batchSize` of 16, 20 `epochs` and a `learning rate` of 0.001. Report the final average PSNR value
#
# 1. 24.18
# 2. 28.12
# 3. 20.43
# 4. 35.46
#
# Answer: 24.18

# %% [markdown]
# #### Question-6
#
# What is the gain value for the ReLU non-linearity used in the code? (Hint: Checkout the documentation for the function used in the code)
#
# 1. $1$
# 2. $\sqrt2$
# 3. $2$
# 4. $\frac{5}{3}$
#
# Answer: $\sqrt2$
